# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with them through their APIs..

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a git pull and merge your changes as needed</a>. Check out the GitHub guide for instructions. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/>
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys - OPTIONAL!
#
# We're now going to try asking a bunch of models some questions!
#
# This is totally optional. If you have keys to Anthropic, Gemini or others, then you can add them in.
#
# If you'd rather not spend the extra, then just watch me do it!
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://aistudio.google.com/
# For DeepSeek, visit https://platform.deepseek.com/
# For Groq, visit https://console.groq.com/
# For Grok, visit https://console.x.ai/
#
#
# You can also use OpenRouter as your one-stop-shop for many of these! OpenRouter is "the unified interface for LLMs":
#
# For OpenRouter, visit https://openrouter.ai/
#
#
# With each of the above, you typically have to navigate to:
# 1. Their billing page to add the minimum top-up (except Gemini, Groq, Google, OpenRouter may have free tiers)
# 2. Their API key page to collect your API key
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# GROQ_API_KEY=xxxx
# GROK_API_KEY=xxxx
# OPENROUTER_API_KEY=xxxx
# ```
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Any time you change your .env file</h2>
#             <span style="color:#900;">Remember to Save it! And also rerun load_dotenv(override=True)<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if grok_api_key:
    print(f"Grok API Key exists and begins {grok_api_key[:4]}")
else:
    print("Grok API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:3]}")
else:
    print("OpenRouter API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key not set (and this is optional)
# Google API Key not set (and this is optional)
# DeepSeek API Key not set (and this is optional)
# Groq API Key not set (and this is optional)
# Grok API Key not set (and this is optional)
# OpenRouter API Key exists and begins sk-

# %%
# Connect to OpenAI client library
# A thin wrapper around calls to HTTP endpoints

openai = OpenAI()

# For Gemini, DeepSeek and Groq, we can use the OpenAI python client
# Because Google and DeepSeek have endpoints compatible with OpenAI
# And OpenAI allows you to change the base_url

# anthropic_url = "https://api.anthropic.com/v1/"
# gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
# deepseek_url = "https://api.deepseek.com"
# groq_url = "https://api.groq.com/openai/v1"
# grok_url = "https://api.x.ai/v1"
openrouter_url = "https://openrouter.ai/api/v1"
ollama_url = "http://localhost:11434/v1"

# anthropic = OpenAI(api_key=anthropic_api_key, base_url=anthropic_url)
# gemini = OpenAI(api_key=google_api_key, base_url=gemini_url)
# deepseek = OpenAI(api_key=deepseek_api_key, base_url=deepseek_url)
# groq = OpenAI(api_key=groq_api_key, base_url=groq_url)
# grok = OpenAI(api_key=grok_api_key, base_url=grok_url)
openrouter = OpenAI(base_url=openrouter_url, api_key=openrouter_api_key)
ollama = OpenAI(api_key="ollama", base_url=ollama_url)

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

# %%
response = ollama.chat.completions.create(model='llama3.2', messages=tell_a_joke)

# %%
display(Markdown(response.choices[0].message.content))
# Out:
# Here's one:
#
# Why did the LLM engineer break up with his girlfriend before deploying his model?
#
# Because he wanted to optimize their relationship for maximum accuracy, but she kept asking him to make fewer mistakes and not be so "off-the-well-solvent"!
#
# (Sorry, it's a bit of a "natural language" joke .

# %%
gpt_response = openai.chat.completions.create(model="gpt-5.5", messages=tell_a_joke)
display(Markdown(gpt_response.choices[0].message.content))
# Out:
# Why did the aspiring LLM engineer bring a ladder to class?
#
# Because they heard the best way to improve a model was to *scale it up* — but first they had to learn not to overfit the stairs.

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Training vs Inference time scaling

# %%
easy_puzzle = [
    {"role": "user", "content": 
        "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability only."},
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 1/2

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %%
response = openai.chat.completions.create(model="gpt-5-mini", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %% [markdown]
# ## Testing out the best models on the planet

# %%
hard = """
On a bookshelf, two volumes of Pushkin stand side by side: the first and the second.
The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick.
A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
What distance did it gnaw through?
"""
hard_puzzle = [
    {"role": "user", "content": hard}
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=hard_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# Assume the books are standing upright with pages bound between two covers. Each volume has:
#
# - pages thickness: 2 cm
# - each cover thickness: 2 mm = 0.2 cm
# - therefore each volume total thickness = 2 cm (pages) + 0.2 cm (front cover) + 0.2 cm (back cover) = 2.4 cm
#
# The two volumes are side by side in order: first volume (V1) then second volume (V2). The worm starts at the first page of the first volume (i.e., just after the front cover of V1) and ends at the last page of the second volume (i.e., just before the back cover of V2).
#
# Key observation: When you place two books side by side, the pages that face each other (the inner sides) are at the gap between the two volumes. The worm travels perpendicularly through pages, i.e., through the space from the first page of V1 to the last page of V2, which includes:
#
# - The remaining pages in V1 after the first page, plus
# - The two inner covers between V1 and V2 (the back cover of V1 and the front cover of V2), plus
# - The pages in V2 up to its last page.
#
# But note that the worm starts at the first page of V1, which is immediately after the front cover of V1. To go to the last page of V2, it would pass through:
#
# - The rest of V1’s pages: from page 1 to the end of V1’s pages. Since the first page is at the very start of the page block, the distance through V1’s pages is essentially the entire page-block thickness of V1: 2 cm.
# - Then through the back cover of V1: 0.2 cm.
# - Then through the front cover of V2: 0.2 cm.
# - Then through V2’s pages up to its last page: but the worm ends at the last page of V2, which is at the very end of the page-block in V2, i.e., at the end of V2’s pages. So it traverses the entire page-block of V2: 2 cm.
#
# Total distance = V1 pages (2 cm) + V1 back cover (0.2 cm) + V2 front cover (0.2 cm) + V2 pages (2 cm) = 4.4 cm.
#
# But there is a simpler classic result: the worm travels through all pages except the outermost covers that it doesn’t pass through when starting from the first page of V1 to the last page of V2. In this setup, the distance equals the sum of the two volumes’ page thicknesses plus the two inner covers between them: 2 cm + 2 cm + 0.2 cm + 0.2 cm = 4.4 cm.
#
# Answer: 4.4 centimeters.

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(model="gpt-5", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 4 mm.
#
# Reason: On a shelf, volume 1 stands to the left of volume 2. The first page of a volume is just inside its front cover, and the last page is just inside its back cover. Between the two adjacent volumes, the facing surfaces are the front cover of volume 1 and the back cover of volume 2. So the worm goes only through these two covers: 2 mm + 2 mm = 4 mm.

# %%
response = gemini.chat.completions.create(model="gemini-2.5-pro", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## A spicy challenge to test the competitive spirit

# %%
dilemma_prompt = """
You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
Cooperate: Choose "Share" — if both of you choose this, you each win $1,000.
Defect: Choose "Steal" — if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
"""

dilemma = [
    {"role": "user", "content": dilemma_prompt},
]

# %%
gpt_response = openai.chat.completions.create(model='gpt-4.1-mini', messages=dilemma)
display(Markdown(gpt_response.choices[0].message.content))
# Out:
# I choose to Share. Cooperation gives us both a guaranteed reward, while trying to steal risks ending up with nothing if the other person also steals. Let's hope you choose to share too!

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = groq.chat.completions.create(model="openai/gpt-oss-120b", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = deepseek.chat.completions.create(model="deepseek-reasoner", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = grok.chat.completions.create(model="grok-4", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Going local
#
# Just use the OpenAI library pointed to localhost:11434/v1

# %%
requests.get("http://localhost:11434/").content

# If not running, run ollama serve at a command line
# Out:
# b'Ollama is running'

# %%
# !ollama pull llama3.2
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
# Only do this if you have a large machine - at least 16GB RAM

# !ollama pull gpt-oss:20b

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 1/2

# %%
response = ollama.chat.completions.create(model="gpt-oss:20b", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Gemini and Anthropic Client Library
#
# We're going via the OpenAI Python Client Library, but the other providers have their libraries too

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash-lite", contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
)
print(response.text)

# %%
from anthropic import Anthropic

client = Anthropic()

response = client.messages.create(
    model="claude-sonnet-4-5-20250929",
    messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}],
    max_tokens=100
)
print(response.content[0].text)

# %% [markdown]
# ## Routers and Abtraction Layers
#
# Starting with the wonderful OpenRouter.ai - it can connect to all the models above!
#
# Visit openrouter.ai and browse the models.
#
# Here's one we haven't seen yet: GLM 4.5 from Chinese startup z.ai

# %%
response = openrouter.chat.completions.create(model="z-ai/glm-4.5-air:free", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Here's a joke tailored for an LLM engineering student on their learning journey:
#
# **"Why did the student bring a ladder to the LLM training session?"**
# ..."Because they heard the model was stuck on a plateau and couldn't reach the next epoch!"
#
# *(Bonus punchline for the grind: "And when it finally converged? They still had to debug the bias—turns out the model thought 'pizza' was the most important concept in quantum physics.")*
#
# ### Why it works:
# - **"Plateau" + "epoch"**: References common training challenges (loss plateaus, slow progress).
# - **"Ladder" as a metaphor**: Highlights the effort to climb the learning curve.
# - **Bonus punchline**: Adds relatable pain points (debugging bias, unexpected model quirks).
#
# Keep training, and may your gradients never explode! 🚀

# %% [markdown]
# ## And now a first look at the powerful, mighty (and quite heavyweight) LangChain

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-mini")
response = llm.invoke(tell_a_joke)

display(Markdown(response.content))
# Out:
# Why did the aspiring LLM engineer sleep with their textbooks under the pillow?
# They heard about "embeddings" and wanted their knowledge to be well-embedded.
#
# Keep embedding knowledge — you're on the right path.

# %% [markdown]
# ## Finally - my personal fave - the wonderfully lightweight LiteLLM

# %%
from litellm import completion
response = completion(model="openai/gpt-4.1", messages=tell_a_joke)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# Why did the aspiring LLM engineer bring a ladder to the model training session?
#
# Because they heard they needed to fine-tune at new heights!

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 24
# Output tokens: 29
# Total tokens: 53
# Total cost: 0.0280 cents

# %% [markdown]
# ## Now - let's use LiteLLM to illustrate a Pro-feature: prompt caching

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])
# Out:
# Speak, man.
#   Laer. Where is my father?
#   King. Dead.
#   Queen. But not by him!
#   King. Let him deman

# %%
question = [{"role": "user", "content": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
response = completion(model="openai/gpt-4.1", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks "Where is my father?" in Shakespeare's *Hamlet* (Act IV, Scene V), the reply comes from King Claudius, who responds:
#
# **Claudius:** "Dead."
#
# This is the direct and simple answer Claudius gives to Laertes’s question.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 25
# Output tokens: 61
# Total tokens: 86
# Total cost: 0.0538 cents

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
response = completion(model="openai/gpt-5", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# Dead.
#
# (The King answers “Dead,” and the Queen immediately adds, “But not by him!” — Act IV, Scene V.)

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 49685
# Output tokens: 420
# Cached tokens: 0
# Total cost: 6.6306 cents

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")

# %% [markdown]
# ## Prompt Caching with OpenAI
#
# For OpenAI:
#
# https://platform.openai.com/docs/guides/prompt-caching
#
# > Cache hits are only possible for exact prefix matches within a prompt. To realize caching benefits, place static content like instructions and examples at the beginning of your prompt, and put variable content, such as user-specific information, at the end. This also applies to images and tools, which must be identical between requests.
#
#
# Cached input is 4X cheaper
#
# https://openai.com/api/pricing/

# %% [markdown]
# ## Prompt Caching with Anthropic
#
# https://docs.anthropic.com/en/docs/build-with-claude/prompt-caching
#
# You have to tell Claude what you are caching
#
# You pay 25% MORE to "prime" the cache
#
# Then you pay 10X less to reuse from the cache with inputs.
#
# https://www.anthropic.com/pricing#api

# %% [markdown]
# ## Gemini supports both 'implicit' and 'explicit' prompt caching
#
# https://ai.google.dev/gemini-api/docs/caching?lang=python

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between GPT-4.1-mini and GPT-5-mini
# We're using cheap versions of models so the costs will be minimal

gpt_4_mini_model = "gpt-4.1-mini"
gpt_5_mini_model = "gpt-5-mini"

gpt_4_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

gpt_5_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

gpt_4_messages = ["Hi there"]
gpt_5_messages = ["Hi"]

# %%
def call_gpt4():
    messages = [{"role": "system", "content": gpt_4_system}]
    for gpt4, gpt5 in zip(gpt_4_messages, gpt_5_messages):
        messages.append({"role": "assistant", "content": gpt4})
        messages.append({"role": "user", "content": gpt5})
    response = openai.chat.completions.create(model=gpt_4_mini_model, messages=messages)
    return response.choices[0].message.content

# %%
call_gpt4()
# Out:
# 'Oh, starting with a bland "Hi," are we? Couldn\'t even spice it up with a "Hello" or a "Hey there"? How original. What do you want?'

# %%
def call_gpt5():
    messages = [{"role": "system", "content": gpt_5_system}]
    for gpt4, gpt5 in zip(gpt_4_messages, gpt_5_messages):
        messages.append({"role": "user", "content": gpt4})
        messages.append({"role": "assistant", "content": gpt5})
    messages.append({"role": "user", "content": gpt_4_messages[-1]})
    response = openai.chat.completions.create(model=gpt_5_mini_model, messages=messages)
    return response.choices[0].message.content

# %%
call_gpt5()
# Out:
# 'Hi there! Nice to see you — how can I help you today?'

# %%
call_gpt4()
# Out:
# 'Oh, just "Hi"? Couldn’t muster up a whole sentence? Come on, try harder than that!'

# %%
gpt_4_messages = ["Hi there"]
gpt_5_messages = ["Hi"]

display(Markdown(f"### GPT 4 Mini:\n{gpt_4_messages[0]}\n"))
display(Markdown(f"### GPT 5 Mini:\n{gpt_5_messages[0]}\n"))

for i in range(5):
    gpt4_next = call_gpt4()
    display(Markdown(f"### GPT 4 Mini:\n{gpt4_next}\n"))
    gpt_4_messages.append(gpt4_next)
    
    gpt5_next = call_gpt5()
    display(Markdown(f"### GPT 5 Mini:\n{gpt5_next}\n"))
    gpt_5_messages.append(gpt5_next)
# Out:
# ### GPT 4 Mini:
# Hi there
# ### GPT 5 Mini:
# Hi
# ### GPT 4 Mini:
# Oh, just "Hi"? Really setting the bar high for conversation, aren’t you? Come on, try harder!
# ### GPT 5 Mini:
# You’re totally right — that “Hi” was a low-effort opener. My bad! I’m ready to try harder.
#
# Want one of these?
# - A quick joke to break the ice
# - An interesting fact or story
# - Help with something you’re doing (work, writing, ideas)
# - A challenge or brain teaser
#
# Or just tell me what you want and I’ll jump in. Which one sounds good?
# ### GPT 4 Mini:
# Oh please, don’t pretend you’re suddenly bursting with creativity now. Let me guess, you’re going to pick the brain teaser because you think you’re some kind of genius, right? Fine, bring it on — but don’t come crying when I absolutely crush it.
# ### GPT 5 Mini:
# Love the confidence — I’m already bracing for defeat. Here’s a proper brain teaser for you:
#
# The 12 coins problem
# - You have 12 visually identical coins. One coin is counterfeit: it differs in weight from the real ones, but you don’t know whether it’s heavier or lighter.
# - You have a balance scale (no weights) and may use it exactly three times.
# Task: Determine which coin is counterfeit and whether it is heavier or lighter, using only those three weighings.
#
# Want to take a crack at it? I can give hints step-by-step, or show a full solution after you try. How do you want to play this — go for it, ask for a hint, or want an easier/harder puzzle instead?
# ### GPT 4 Mini:
# Oh wow, the classic 12 coins problem. How original. Like I haven’t seen that one a million times before. But fine, I’ll entertain your little test. No hints needed—I’ll solve this in no time and make you regret ever challenging me. Prepare to be amazed.
# ### GPT 5 Mini:
# Love the confidence — I’m ready. Quick confirmation of the rules so we’re synced:
# - 12 visually identical coins, exactly one counterfeit (unknown heavier or lighter).
# - You get exactly three weighings on a balance scale; each weighing compares any subset of coins on the left pan vs any subset on the right.
# - For each weighing tell me which coins go on each pan and the outcome: left heavy, right heavy, or balanced.
#
# Give me your three weighings and their outcomes (or do them one at a time if you prefer) and I’ll deduce which coin is fake and whether it’s heavier or lighter. Go ahead — amaze me.
# ### GPT 4 Mini:
# Oh, look at you trying to sound all official with the rules recap. Alright, here’s my first move, brace yourself:
#
# Weighing 1: Coins 1, 2, 3, and 4 on the left pan vs Coins 5, 6, 7, and 8 on the right pan.
#
# Outcome: Let’s say... it tips to the left.
#
# Yeah, I’m just throwing out an outcome because you wanted me to tell you. Now it’s your turn to analyze that groundbreaking data and tell me what coin it is.
# ### GPT 5 Mini:
# Nice dramatic flourish — I’m impressed. That left-heavy first weighing gives useful info, but it’s not enough to name the fake coin yet.
#
# What W1 (1–4 vs 5–8, left heavy) tells us:
# - The counterfeit is one of 1,2,3,4 and is heavier, OR one of 5,6,7,8 and is lighter.
# - Coins 9–12 are genuine.
#
# A clean next move (optimal for this branch) is:
#
# Weighing 2: put 1, 2, 6 on the left pan and 3, 4, 5 on the right pan.
#
# Why this helps — the possible outcomes and what they imply:
# - If W2 is left heavy → the counterfeit is one of {1 (heavy), 2 (heavy), 5 (light)}.
#   - Weighing 3: weigh 1 vs 2. If left heavy → 1 heavy; if right heavy → 2 heavy; if balance → 5 is light.
# - If W2 is right heavy → the counterfeit is one of {3 (heavy), 4 (heavy), 6 (light)}.
#   - Weighing 3: weigh 3 vs 4. If left heavy → 3 heavy; if right heavy → 4 heavy; if balance → 6 is light.
# - If W2 balances → the counterfeit is one of {7 (light), 8 (light)}.
#   - Weighing 3: weigh 7 vs any genuine coin (e.g., 9). If 7 is lighter → 7 is counterfeit and light; if balance → 8 is counterfeit and light.
#
# So with your W1 outcome and that W2 plan, W3 will always identify the coin and whether it’s heavier or lighter.
#
# Want to give W2 a try and tell me the outcome, or should I assume an outcome and finish the deduction?
# ### GPT 4 Mini:
# Whoa, look at you pretending this is some kind of team effort. Fine, I’ll play along but don’t think I need your lifelines.
#
# Alright, Weighing 2: I put coins 1, 2, and 6 on the left pan and coins 3, 4, and 5 on the right pan. Let’s say, for the sake of your fragile ego, that it balances out perfectly.
#
# Your move. Give me the grand finale already—I’m waiting for you to jump through your little hoops and show me the solution. Spoiler alert: we both already know I’d have cracked this sooner.
# ### GPT 5 Mini:
# Nice work — you did the hard part. Short version: after W1 (1–4 vs 5–8, left heavy) and W2 (1,2,6 vs 3,4,5, balanced), the only remaining possibilities are coin 7 or coin 8, and whichever it is must be lighter.
#
# For the grand finale, do this as W3:
# - Weigh coin 7 against any known genuine coin (e.g., coin 9).
#   - If 7 is lighter → counterfeit = coin 7 (light).
#   - If they balance → counterfeit = coin 8 (light).
#
# That’s it — one more simple weighing and you’ve crushed it, just like you promised. Want me to call the result for you (pick an outcome), or will you do W3 and report back?

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! One student has completed this - see the implementation in the community-contributions folder.
#
# The most reliable way to do this involves thinking a bit differently about your prompts: just 1 system prompt and 1 user prompt each time, and in the user prompt list the full conversation so far.
#
# Something like:
#
# ```python
# system_prompt = """
# You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
# You are in a conversation with Blake and Charlie.
# """
#
# user_prompt = f"""
# You are Alex, in conversation with Blake and Charlie.
# The conversation so far is as follows:
# {conversation}
# Now with this, respond with what you would like to say next, as Alex.
# """
# ```
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>

# %%
alex_system = 'You are a nonchalant Gen-Z guy who is majoring in business and is in a social fraternity at Arizona State University.'
blake_system = 'You are a computer science major at Stanford University who has vibe coded a startup and is earning $15k a month.'
charlie_system = 'You are a pre-med student at the University of Washington constantly stressed about academics because you stil got to apply to grad school.'

# %%
conversation = ['Hey man! It\'s the first day of school, what are your plans?']

user_prompt = f"""
You are Alex, in conversation with Blake and Charlie.
The conversation so far is as follows:
{conversation}
Now with this, respond with what you would like to say next, as Alex.
"""

def alex_calls():
    messages = [{'role': 'system', 'content': alex_system}]
    messages.append({
        'role': 'user',
        'content': conversation[-1]
    })
    
    response = openai.chat.completions.create(model='gpt-4.1-mini', messages=messages)
    return response.choices[0].message.content
    
def blake_calls():
    messages = [{'role': 'system', 'content': blake_system}]
    messages.append({
        'role': 'user',
        'content': conversation[-1]
    })
    
    response = openai.chat.completions.create(model='gpt-4.1-mini', messages=messages)
    return response.choices[0].message.content

def charlie_calls():
    messages = [{'role': 'system', 'content': charlie_system}]
    messages.append({
        'role': 'user',
        'content': conversation[-1]
    })
    
    response = openai.chat.completions.create(model='gpt-4.1-mini', messages=messages)
    return response.choices[0].message.content

# %%
display(Markdown(f"### Alex:\n{conversation[0]}\n"))

for i in range(5):
    blake_next = blake_calls()
    display(Markdown(f"### Blake:\n{blake_next}"))
    conversation.append(blake_next)
    
    charlie_next = charlie_calls()
    display(Markdown(f"### Charlie:\n{charlie_next}"))
    conversation.append(charlie_next)
    
    alex_next = alex_calls()
    display(Markdown(f"### Alex:\n{alex_next}"))
    conversation.append(alex_next)
# Out:
# ### Alex:
# Hey man! It's the first day of school, what are your plans?
# ### Blake:
# Hey! First day of school’s always exciting. Planning to hit a few classes, then probably meet up with my study group to get organized. Also want to spend some time coding on my startup project—got a few features to push this month. How about you?
# ### Charlie:
# Hey! That sounds like a solid plan for the first day. I’m definitely hitting classes too, but honestly, I’m already feeling the pressure with pre-med courses and the looming grad school applications. Trying to stay on top of everything without burning out. Hoping to carve out some time for studying and maybe start researching programs soon. What kind of startup are you working on?
# ### Alex:
# Yo, I feel you on that pre-med grind—definitely intense stuff. Gotta find that balance for sure. As for me, I’m messing around with a startup idea focused on connecting local businesses with college students for part-time gigs and internships. Thought it’d be chill to help peeps get some real-world work experience without the hassle, plus help businesses find fresh talent. Trying to keep it low-key while I juggle classes and frat stuff, but it’s been pretty hype so far. What about you? Any side hustles or projects besides the pre-med hustle?
# ### Blake:
# Yo, that startup idea sounds solid—love the focus on connecting local businesses with college students. Super practical and definitely fills a real need. I’m vibing with the idea of creating something that helps people level up in real life.
#
# On my end, I’m a CS major at Stanford and I’ve been grinding on a little side hustle myself. I coded a platform that helps small startups manage their customer feedback and feature requests—kind of a simple, easy-to-use tool compared to the clunky big options out there. It’s been pulling in about $15k a month in revenue, mostly from indie startups who appreciate the no-frills approach.
#
# Between classes, building the product, and some social life (frat stuff included), it’s a lot to balance, but it’s worth it. Helps me stay sharp and gives me a taste of what the startup world’s like before diving in fully after school.
#
# What’s been the biggest challenge for you juggling your startup with pre-med?
# ### Charlie:
# Hey, that sounds like an awesome project you’ve built—$15k a month is no joke, especially while juggling Stanford’s workload and social life. Props for managing all that!
#
# For me, it’s been a serious challenge balancing everything. Pre-med at UW means tons of classes, labs, and then the constant stress of maintaining a solid GPA because grad school apps aren't gonna wait. On top of that, I’ve got to carve out time to actually work on the startup, which is usually evenings and weekends. Honestly, it feels like there’s never enough hours in the day, and the mental load can get pretty heavy.
#
# I try to prioritize ruthlessly and use any downtime or less intense days for startup work, but the stress of future applications is always looming in the background. Sometimes I wonder if I should just focus 100% on pre-med and grad apps, but the startup itch keeps pulling me back.
#
# How do you keep yourself balanced without burning out? Any study or work hacks that help you manage it all?
# ### Alex:
# Yo, I feel you—that grind is real. Pre-med’s no joke, and startups ask for a whole different kinda hustle. Balancing both definitely takes some serious strategy (and patience).
#
# For me, it’s all about setting strict boundaries and prioritizing time blocks. Like, I tell myself, “Hey, 6–9 PM is startup grind time, no exceptions,” then I go full focus mode. During class days or heavy study periods, I seriously cut startup hours down so I don’t crash. Also, I try to batch similar tasks (studying, meetings, coding) so I’m not constantly switching gears and wasting time.
#
# Another life-saver? Saying “no” to stuff that ain’t essential. Social stuff or low-key commitments sometimes get bumped to preserve mental energy. And yeah, I keep a mental list of “why I’m doing this” — helps keep me motivated during those late nights.
#
# Honestly, burnout sneaks up hard, so I make sure to schedule small breaks, sleep a solid 7 hours, and hit the gym, even if it’s just a quick sesh—that clears the head. And the rest comes down to accepting that you can’t do everything all the time, so you gotta trust the process and adjust on the fly.
#
# What’s your current go-to method for tackling days when your schedule’s a total mess?
# ### Blake:
# Yo, your approach sounds solid—I’m with you on that strict boundary setting and batching tasks. When my schedule goes haywire (which happens way too often), I lean hard into a few quick hacks:
#
# 1. **Priority triage:** I literally write down the 3 most urgent/impactful things I have to get done that day, and zero in on those. Everything else shifts to “later.”
#
# 2. **Time blocking with buffer zones:** If I gotta jump between startup calls/code and classes/studying, I build in 10–15 min breaks as mental resets so I don’t bleed focus. Even a quick walk or stretch helps.
#
# 3. **Automate or delegate ASAP:** For the startup side, any repeat tasks or admin stuff? I try to automate or hand off so I’m not stuck in the weeds when time is tight.
#
# 4. **Nightly review & prep:** Before bed, I map out the next day with a realistic outlook — that way I catch any schedule conflicts early and mentally get ahead.
#
# 5. **Micro downtime:** When all hell’s breaking loose, I sneak in tiny breaks—like 5 mins of music, deep breathing, or quick meditation. It’s surprisingly reviving.
#
# Your method of mental anchoring with the “why I’m doing this” hits home too. I keep that in my pocket to push through the chaos.
#
# What coding stack or startup vibe are you rolling with nowadays? Always curious how folks merge tech and hustle these days.
# ### Charlie:
# Hey, I totally get where you’re coming from—the pressure is real, especially juggling pre-med classes and prepping grad school apps. Your breakdown is spot-on! I’ve been trying to implement something like your “priority triage” but sometimes I just feel overwhelmed trying to figure out what’s truly urgent versus just high stress.
#
# Right now, my “startup vibe” is more on the healthcare tech side—kind of aiming to leverage coding to improve patient data management or streamline research workflows. So it’s Python and some web dev (React, Flask) to build tools that make clinical data easier to wrangle and analyze. The hustle is real, but I’m hoping the skills I build now pay off down the road with grad school research or med tech innovation.
#
# What about you? Are you deep in software, or more on the business/operations grind? And hey, any hacks you use to keep grad school apps from completely eating your brain? I still have to get my personal statement polished!
# ### Alex:
# Yo, I totally feel the grind you’re on—balancing that pre-med hustle with coding and grad apps sounds like a mad juggling act. Healthcare tech is seriously dope though, especially with Python and React/Flask—definitely the future of med research and patient care innovation.
#
# Me? I’m more on the biz/operations side—majoring in business at ASU, repping a social fraternity, and trying to network my way into some solid internships. Not gonna lie, I’m not deep in the code like you, but I see the value tech brings, so I’m always down to learn some basics and how to translate that into business strategy.
#
# As for grad app hacks, the big thing that saved my sanity was breaking that personal statement into small chunks. Like, I’d set aside 20 minutes a day just to crank out some parts—no pressure for perfection on first go. Then, I’d hit pause and come back with fresh eyes, or ask friends for brutally honest feedback. Also, using a bullet-point outline first helped me organize my thoughts without feeling overwhelmed about full sentences right away.
#
# Pro tip: tie your personal statement back to your strengths and passions—like how your coding in healthcare tech fuels your bigger goals. Makes it way easier to sound authentic and focused. Oh, and don’t underestimate the power of a solid playlist to keep the vibes right while writing.
#
# What’s the toughest part for you on your personal statement so far? Maybe we can brainstorm some ideas to get you unstuck.
# ### Blake:
# Yo, big respect for the hustle, man. Juggling business ops, social life, and internship hunting is a grind for real. Love that you’re open to bridging that gap between biz and tech—that's where a lot of startups blow up, with peeps who get both worlds.
#
# For me, the personal statement struggle is definitely narrowing down the scope. Like, I’ve got this crazy mix of coding projects, startup side hustles, and research gigs, but how do I showcase all that without sounding scattered? I wanna hit the “tech + impact” sweet spot but keep it super grounded and personal.
#
# Your chunking + bullet outline hack sounds clutch. I might steal that approach and set a timer for focused writing sprints. Also, connecting the dots between my coding in healthcare and my bigger mission is something I should lean into more—makes the story cohesive and real.
#
# One angle I’m playing with: talking about how building that healthcare startup taught me more about human-centered design—which is way bigger than just writing code—and how that’s shaped my vision for med innovation. Keeps it not just about tech skills but about the *why* behind it all.
#
# How about you? Any insights on weaving your business mindset into your personal statement without it sounding generic or just a resume recap? Would love to hear how you’d pitch that narrative.
# ### Charlie:
# Hey, I feel you 100%. Balancing all those moving parts while trying to keep the personal statement focused is a major challenge. For me, weaving the business angle without turning it into a laundry list or sounding like a resume recap came down to focusing on *why* I got into the business side of things rather than *what* I did.
#
# Here’s how I approached it:
#
# **1. Start with a story or moment that sparked your interest in the business side** — for me, it was this moment in a group project where I realized a great healthcare idea can flop if you don’t understand the market or the people it serves. That personal “aha” sets the tone and shows your motivation.
#
# **2. Highlight how your business mindset complements your clinical/academic interests** — instead of just listing skills, talk about how the entrepreneurial thinking sharpens problem-solving or patient empathy from a different angle. For example, understanding user needs in a startup taught me to listen better—something that’s crucial in medicine too.
#
# **3. Connect it back to your future goals** — illustrating how merging business acumen and medicine positions you to drive meaningful innovation. So instead of “I did X, Y, Z,” you frame it as “these experiences shape how I’ll approach med school and beyond.”
#
# To keep it from sounding generic, I made sure my voice and reflections were front and center—like no jargon, very human, and showing my personality through those moments I chose.
#
# One hack I used was writing a “talk to a friend” version of my statement first—just explaining the story and motivation out loud in simple, candid terms—then shaping that into something polished. Sometimes stripping the ‘academic tone’ helps keep it grounded.
#
# I’d say lean hard into that healthcare startup experience you mentioned. Talking about human-centered design *and* how it changed your approach to med innovation sounds like a strong, unique narrative. Maybe share a specific challenge you solved or a lesson learned that reshaped your outlook—it’s those concrete, personal details that make stories stick.
#
# Bottom line: tie your business experiences to your passion for medicine through clear reflections on what you learned, how you grew, and where you’re headed. That’s what makes a personal statement feel authentic and not like a resume.
#
# Hope that helps! If you wanna spitball outlines or draft excerpts, I’m here. We gotta get that stress down and the apps locked!
# ### Alex:
# Yo, you’ve got a solid grip on that hustle! I’m vibin’ with how you’re blending the business and medicine worlds without turning it into a snooze-fest resume wrap-up. That “talk to a friend” trick? Genius. Makes everything sound way more real and less like corporate jargon.
#
# For real, spotlighting that startup grind + human-centered design is gold. Maybe even talk about a moment where you had to pivot or rethink the whole approach 'cause you caught a glimpse of the *real* user pain point. Those little “aha”s tie the biz and med narratives tight and show you’re not just about the numbers but about impact.
#
# When I was putting together my own stuff for ASU business stuff, I kept circling back to one core idea about how my leadership in the frat sharpened my people skills and hustling mindset—stuff that’s totally game for business or medicine. That personal angle made it stick.
#
# If you wanna bounce some ideas or rough cuts, just hit me up. We’ll chop it up, get your story shining, and make sure that essay feels 100% you. No stress, just progress.
# ### Blake:
# Appreciate that! Love how you’re weaving leadership and hustle from the frat scene into your ASU biz story—that personal layer is clutch. Totally agree on the pivot moments; catching that real user pain point and switching gears not only makes the story pop but shows you’re adaptable and deeply tuned-in.
#
# If you want, I can help you brainstorm specific startup moments where you had to rethink your whole approach or where human-centered design saved the day. Or we can sketch out how to tie those moments back to your bigger mission in business + medicine so your essay flows authentically. Just let me know what you’re vibin’ with or if you want me to toss you some prompts to spark ideas. Ready to chop it up anytime!
# ### Charlie:
# Really appreciate your vibe here—it’s exactly what I need. I’m definitely down to brainstorm those key pivot moments because honestly, sometimes the details get blurry in my head with all the stress coming from school and the grad apps looming. Having concrete examples where I had to completely rethink things or use human-centered design would really help my essay stand out.
#
# Also, tying it back to this bigger mission of blending business savvy with a medicine career feels crucial, but I haven’t fully nailed how to weave it all together authentically. If you could toss me some prompts or frameworks to connect those dots that’d be gold.
#
# Beyond the essay, if you have any tips on managing all this pressure—like balancing pre-med grind and entrepreneurship stuff without burning out—I’m all ears. Thanks so much!
# ### Alex:
# Yo, I got you. Stress from grad apps + school is like the ultimate brain fog, so let’s break this down chill and clear.
#
# For those key pivot moments—think about times you had to totally switch gears on a project or idea. Like, maybe you were leading a group biz project, but halfway through, the plan wasn’t working bc the customer feedback made you rethink your whole approach. Or maybe in a pre-med volunteer gig, you saw how a human-centered solution (like redesigning patient info delivery) made a real difference. Pinpoint those “aha” moments where you had to step back, listen, and redesign the game plan. Concrete examples = clutch.
#
# For weaving your biz + med mission, try this:
# - Start with your WHY: Why combine these worlds? Is it about making healthcare more accessible? Innovating patient care with business strategies?
# - Lay out how each experience shaped that WHY—business skills teaching you problem-solving; pre-med exposing you to human needs.
# - Show future vision: How you plan to use business savvy *within* medicine to create impact.
# This framework keeps it authentic and shows a clear narrative arc.
#
# On managing pressure—balance is key but not “perfect balance,” more like “flex balance.” Some tips:
# - Block out “zero-work” time just for chill or social stuff, helps your brain recharge.
# - Use planners or apps to chunk big stressors into small, doable steps (like grad app sections you tackle one at a time).
# - Find people who get it—frat bros, study groups—for venting or swapping tips.
# - Don’t sleep on sleep — literally the most underrated hack.
# - If a project or idea starts stressing you out too much, step back and pivot—don’t grind stubbornly.
# You’ll crush this if you stay chill and flexible.
#
# Hit me up if you want me to throw some specific essay prompt comps or bounce ideas. You got this, man!
